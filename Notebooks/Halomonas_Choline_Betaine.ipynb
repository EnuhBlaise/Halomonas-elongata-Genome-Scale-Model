# %%
# %%capture
pip install escher

# %%
# %%capture
pip install cobra

# %%
import escher
import cobra 
from escher import *

# %%
model = cobra.io.read_sbml_model("/content/drive/MyDrive/Halomonas_Model_devt/Halomonas_elongata_Model.xml")

# %%
model.reactions.EX_chol_e
# Out:
# <Reaction EX_chol_e at 0x7fc384898bd0>

# %%
model.medium
# Out:
# {'EX_asn__L_e': 9.0,
#  'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_glc__D_e': 10.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
#lets maintain the flux of choline to -2
medium = model.medium
medium['EX_chol_e'] = 2.0
model.medium = medium
model.reactions.EX_chol_e.lower_bound = -2.0

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.4954864854563703</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>9</td>
#       <td>4</td>
#       <td>33.96%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.007538</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>2</td>
#       <td>5</td>
#       <td>9.43%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.007538</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0001448</td>
#       <td>0</td>
# ...

# %%
from cobra.flux_analysis import flux_variability_analysis

# %%
FVA = flux_variability_analysis(model)

# %%
FVA.head()
# Out:
#                minimum       maximum
# 14GLUCANabcpp      0.0  0.000000e+00
# 14GLUCANtexi       0.0  0.000000e+00
# 1PPDCRc            0.0  8.288650e-12
# 2AGPE120tipp       0.0  1.289346e-11
# 2AGPE140tipp       0.0  1.775997e-11

# %%
FVA[FVA.index =='EX_glyb_e' ]
# Out:
#             minimum   maximum
# EX_glyb_e  1.776955  1.776955

# %%
#lets increase the flux of betaine little bit
medium = model.medium
medium['EX_chol_e'] = 5.0
model.medium = medium
model.reactions.EX_chol_e.lower_bound = -5.0

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.5543964575856217</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>9</td>
#       <td>4</td>
#       <td>29.75%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.007835</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>5</td>
#       <td>5</td>
#       <td>20.66%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.007835</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0001505</td>
#       <td>0</td>
# ...

# %%
FVA2 = flux_variability_analysis(model)

# %%
FVA2[FVA2.index =='EX_glyb_e' ]
# Out:
#             minimum   maximum
# EX_glyb_e  4.768169  4.768169
