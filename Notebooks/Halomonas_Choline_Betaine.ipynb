# %%
# %%capture
pip install escher

# %%
# %%capture
pip install cobra

# %%
import escher
import cobra 
from escher import *

# %%
model = cobra.io.read_sbml_model('/content/drive/MyDrive/Model_devt_Ch/(Complete_Canadensis.xml')

# %%
model.reactions.EX_chol_e
# Out:
# <Reaction EX_chol_e at 0x7fd2cb4d9190>

# %%
model.medium
# Out:
# {'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_glc__D_e': 10.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
#lets maintain the flux of choline to -2
medium = model.medium
medium['EX_chol_e'] = 2.0
model.medium = medium
model.reactions.EX_chol_e.lower_bound = -2.0

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.4867175849499137</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.007494</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>2</td>
#       <td>5</td>
#       <td>14.29%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.007494</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.000144</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.001021</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.02091</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>85.71%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.281</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.01249</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0009949</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>15.48</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.505</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>1.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.3608</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.000491</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-1.77</td>
#       <td>1</td>
#       <td>20.65%</td>
#     </tr>
#     <tr>
#       <td>glyb_e</td>
#       <td>EX_glyb_e</td>
#       <td>-1.36</td>
#       <td>5</td>
#       <td>79.33%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-45.36</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-12.27</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>4hba_c</td>
#       <td>sink_4hba_c</td>
#       <td>-0.0003211</td>
#       <td>7</td>
#       <td>0.03%</td>
#     </tr>
#   </tbody>
# </table>

# %%
from cobra.flux_analysis import flux_variability_analysis

# %%
FVA = flux_variability_analysis(model)

# %%
FVA.head()
# Out:
#                minimum       maximum
# 12DGR161tipp       0.0  3.067190e-12
# 12DGR181tipp       0.0  3.067190e-12
# 14GLUCANabcpp      0.0  0.000000e+00
# 14GLUCANtexi       0.0  0.000000e+00
# 1PPDCRc            0.0  2.066978e-11

# %%
FVA[FVA.index =='EX_glyb_e' ]
# Out:
#             minimum  maximum
# EX_glyb_e  0.273731  1.35997

# %%
#lets increase the flux of betaine little bit
medium = model.medium
medium['EX_chol_e'] = 5.0
model.medium = medium
model.reactions.EX_chol_e.lower_bound = -5.0

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.4867175849432956</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.007494</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chol_e</td>
#       <td>EX_chol_e</td>
#       <td>2.194</td>
#       <td>5</td>
#       <td>15.45%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.007494</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.000144</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.001021</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.02091</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>84.55%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.281</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.01249</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0009949</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>15.48</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2.699</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>1.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.3608</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.000491</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-1.77</td>
#       <td>1</td>
#       <td>18.55%</td>
#     </tr>
#     <tr>
#       <td>glyb_e</td>
#       <td>EX_glyb_e</td>
#       <td>-1.554</td>
#       <td>5</td>
#       <td>81.42%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-45.55</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-12.47</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>4hba_c</td>
#       <td>sink_4hba_c</td>
#       <td>-0.0003211</td>
#       <td>7</td>
#       <td>0.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
FVA2 = flux_variability_analysis(model)

# %%
FVA2[FVA2.index =='EX_glyb_e' ]
# Out:
#             minimum  maximum
# EX_glyb_e  0.273731  4.35997
