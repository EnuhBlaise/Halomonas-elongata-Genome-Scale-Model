# %%
# %%capture
pip install cobra

# %%
# %%capture
pip install cobramod

# %%
import cobra
import cobramod
import os
import pandas as pd

# %%
os.chdir("/content/drive/MyDrive/Halomonas_Model_devt")

# %%
pwd
# Out:
# '/content/drive/MyDrive/Halomonas_Model_devt'

# %%
# %ls

# %%
# %cd Notebooks/

# %%
# %ls

# %%
# %cd ../

# %%
model= cobra.io.read_sbml_model("/content/drive/MyDrive/Halomonas_Model_devt/Complete_HalomonasPolished.xml") #ths model phb is not produced still
# Out:
# MNXR98569 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98641 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR97994 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98643 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98014 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98022 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98024 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98025 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98027 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98700 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98043 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98047 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98181 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98062 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98256 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98067 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98349 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98180 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98086 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98405 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98278 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98058 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98197 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98198 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98208 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98196 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98339 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98210 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98211 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98854 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98225 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98226 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98230 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98786 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98229 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98239 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98731 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98257 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98292 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98389 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98255 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98579 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98591 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98930 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98977 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98286 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98261 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98336 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98733 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98737 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98269 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98277 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98465 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98724 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98813 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98131 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98845 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98293 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98294 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98686 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98866 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98748 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98305 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98306 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98308 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98318 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR97995 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98341 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98344 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98346 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98756 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98761 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98356 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98152 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR97619 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98490 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98712 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98815 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98353 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98359 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98371 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98384 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98387 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98799 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98583 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98392 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98414 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98393 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98398 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98402 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98403 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98011 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98694 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98424 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98425 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98427 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98431 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98929 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98435 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98555 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98650 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98651 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98807 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98808 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98996 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98459 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98461 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98638 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR97582 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98464 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98466 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98468 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98469 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98470 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98474 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98475 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98449 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98476 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98477 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98478 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98479 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98491 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98489 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98492 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98494 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98500 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98523 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98526 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98527 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98528 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98529 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98530 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98535 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98534 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98540 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98539 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98539 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98554 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98557 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98630 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98574 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98575 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98576 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98577 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98599 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98597 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98598 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98603 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98602 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98629 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98640 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98632 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98642 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98848 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98654 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98656 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98658 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98064 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98665 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98664 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98956 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98677 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98681 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98682 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98687 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98184 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98699 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98182 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98183 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98713 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98695 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98730 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98734 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98735 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98736 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98738 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98739 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98741 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98775 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98777 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98778 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98770 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98771 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98773 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98769 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98768 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98772 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98747 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98753 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98763 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98764 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99011 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98781 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98782 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98789 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98790 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99020 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98791 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR97603 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99026 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98802 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98810 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98814 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98818 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98817 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98827 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98856 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98857 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98867 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98888 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98892 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98894 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98895 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98898 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98935 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99024 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98991 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99005 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99031 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98900 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98901 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98940 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99025 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98911 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98921 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98920 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98923 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98925 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98661 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98917 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98949 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98191 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98954 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98955 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98966 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98974 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98980 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98982 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98983 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98986 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98988 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98995 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR98997 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99014 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99019 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99023 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99041 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99049 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR99051 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# MNXR96131 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id

# %%
model
# Out:
# <Model Halomonas_RAST at 0x7f8bd21f4490>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.0016325595915014</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>5.431</td>
#       <td>4</td>
#       <td>40.04%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>9.7E-05</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>9.7E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0006877</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.01409</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fru_e</td>
#       <td>EX_fru_e</td>
#       <td>3.922</td>
#       <td>6</td>
#       <td>43.37%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1.5</td>
#       <td>6</td>
#       <td>16.59%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.1893</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.008415</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0006703</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>1.206</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.9565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.2431</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0003308</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.2389</td>
#       <td>2</td>
#       <td>3.71%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-6.436</td>
#       <td>1</td>
#       <td>50.01%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.0006489</td>
#       <td>2</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-20.07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mal__L_e</td>
#       <td>EX_mal__L_e</td>
#       <td>-1.486</td>
#       <td>4</td>
#       <td>46.19%</td>
#     </tr>
#     <tr>
#       <td>succ_e</td>
#       <td>EX_succ_e</td>
#       <td>-0.002113</td>
#       <td>4</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>4hba_c</td>
#       <td>sink_4hba_c</td>
#       <td>-0.0002163</td>
#       <td>7</td>
#       <td>0.01%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.medium
# Out:
# {'EX_asn__L_e': 1000.0,
#  'EX_bz_e': 9.7e-05,
#  'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_fru_e': 10.0,
#  'EX_glc__D_e': 1.5,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
medium = model.medium
medium["EX_fru_e"] = 0.0
medium["EX_glc__D_e"] = 10.0
medium["EX_bz_e"] = 0.0
model.medium = medium

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
medium = model.medium
medium["EX_bz_e"] = 9.7e-05
model.medium = medium

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.001632559591502</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>5.431</td>
#       <td>4</td>
#       <td>39.90%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>9.7E-05</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>9.7E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0006877</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.01409</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>5.452</td>
#       <td>6</td>
#       <td>60.09%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.1893</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.008415</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0006703</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>1.466</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.9565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.2431</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0003308</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-0.2389</td>
#       <td>2</td>
#       <td>3.66%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-6.721</td>
#       <td>1</td>
#       <td>51.50%</td>
#     </tr>
#     <tr>
#       <td>glyclt_e</td>
#       <td>EX_glyclt_e</td>
#       <td>-0.0006489</td>
#       <td>2</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-20.33</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mal__L_e</td>
#       <td>EX_mal__L_e</td>
#       <td>-1.46</td>
#       <td>4</td>
#       <td>44.76%</td>
#     </tr>
#     <tr>
#       <td>succ_e</td>
#       <td>EX_succ_e</td>
#       <td>-0.002113</td>
#       <td>4</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>4hba_c</td>
#       <td>sink_4hba_c</td>
#       <td>-0.0002163</td>
#       <td>7</td>
#       <td>0.01%</td>
#     </tr>
#   </tbody>
# </table>

# %%
from cobra.flux_analysis import flux_variability_analysis

# %%
FVA = flux_variability_analysis(model)

# %%
type (FVA)
# Out:
# pandas.core.frame.DataFrame

# %%
FVA.to_excel("FVA.xlsx")

# %%
# %ls
# Out:
#  BIGG_universal_model.json                     HalomonasmodelV1.json
#  CarbonSimulations.csv                         HalomonasmodelV1.xml
# 'CarveMe Models'/                              HalomonasmodelV2.xml
#  Complete_Halomonas.json                       HalomonasmodelV3.json
#  Complete_HalomonasPolished.xml                HalomonasmodelV3.xml
#  Complete_Halomonas.xml                        HalomonasProkkamodelV1.xml
#  consistent_model.xml                          Halomonas_RASTV1.xml
#  data/                                         Halomonas_RASTV3.json
# '(+DemandPHBrxns)_Model.xml'                   Halomonas_RASTV3.xml
# 'extract reactions'/                           Halomonas_RAST.xml
#  FVA.xlsx                                      Notebooks/
# 'Genome Scale Model Reconstruction Process'/   ProkkaHalomonasModel.xml
#  Halomonas_annotation_feature_dna_Model.xml    Readme.txt
#  Halomonas_COBRAModel.xml                      universal_model.json
#  HalomonasModelFBC.xml

# %%
FVA
# Out:
#                   minimum       maximum
# 14GLUCANabcpp     0.00000  0.000000e+00
# 14GLUCANtexi      0.00000  0.000000e+00
# 1PPDCRc           0.00000  2.515832e+02
# 2AGPE120tipp      0.00000  4.385042e+02
# 2AGPE140tipp      0.00000  4.385042e+02
# ...                   ...           ...
# EutB          -1000.00000  1.000000e+03
# ASPSALy       -1000.00000  9.988930e+02
# ECTOtex           0.00000  0.000000e+00
# ECTOabcpp      -326.22627 -3.615486e-13
# EX_ecto__L_e      0.00000  3.262263e+02
#
# [2306 rows x 2 columns]

# %%
model.metabolites.phb_c.summary()
# Out:
# <h3>phb_c</h3><p>C4H8O3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
model.metabolites.ecto__L_c.summary()
# Out:
# <h3>ecto__L_c</h3><p>C6H10N2O2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
model.metabolites.atp_c.summary()
# Out:
# <h3>atp_c</h3><p>C10H12N5O13P3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>92.49%</td>
#       <td>68.11</td>
#       <td>ASPK</td>
#       <td>asp__L_c + atp_c &lt;=&gt; 4pasp_c + adp_c</td>
#     </tr>
#     <tr>
#       <td>2.96%</td>
#       <td>2.183</td>
#       <td>ATPS4rpp</td>
#       <td>adp_c + 4.0 h_p + pi_c --&gt; atp_c + h2o_c + 3.0 h_c</td>
#     </tr>
#     <tr>
#       <td>4.54%</td>
#       <td>3.344</td>
#       <td>PGK</td>
#       <td>3pg_c + atp_c &lt;=&gt; 13dpg_c + adp_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.39%</td>
#       <td>-0.2869</td>
#       <td>ACGK</td>
#       <td>acglu_c + atp_c --&gt; acg5p_c + adp_c</td>
#     </tr>
#     <tr>
#       <td>2.66%</td>
#       <td>-1.959</td>
#       <td>ADK1</td>
#       <td>amp_c + atp_c &lt;=&gt; 2.0 adp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-9.7E-05</td>
#       <td>ADNK1</td>
#       <td>adn_c + atp_c --&gt; adp_c + amp_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.2389</td>
#       <td>ADSK</td>
#       <td>aps_c + atp_c --&gt; adp_c + h_c + paps_c</td>
#     </tr>
#     <tr>
#       <td>0.13%</td>
#       <td>-0.097</td>
#       <td>ALAALAr</td>
#       <td>2.0 ala__D_c + atp_c &lt;=&gt; adp_c + alaala_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.39%</td>
#       <td>-0.2869</td>
#       <td>ARGSS</td>
#       <td>asp__L_c + atp_c + citr__L_c --&gt; amp_c + argsuc_c + h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.12%</td>
#       <td>-0.0919</td>
#       <td>ATPPRT</td>
#       <td>atp_c + prpp_c --&gt; ppi_c + prbatp_c</td>
#     </tr>
#     <tr>
#       <td>1.65%</td>
#       <td>-1.216</td>
#       <td>CBPS</td>
#       <td>2.0 atp_c + gln__L_c + h2o_c + hco3_c --&gt; 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>1.45%</td>
#       <td>-1.068</td>
#       <td>CDPMEK</td>
#       <td>4c2me_c + atp_c --&gt; 2p4c2me_c + adp_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.1557</td>
#       <td>CTPS2</td>
#       <td>atp_c + gln__L_c + h2o_c + utp_c --&gt; adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0006877</td>
#       <td>CUabcpp</td>
#       <td>atp_c + cu2_p + h2o_c --&gt; adp_c + cu2_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>1.45%</td>
#       <td>-1.068</td>
#       <td>CYTK1</td>
#       <td>atp_c + cmp_c &lt;=&gt; adp_c + cdp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0006489</td>
#       <td>DHFS</td>
#       <td>atp_c + dhpt_c + glu__L_c --&gt; adp_c + dhf_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0005587</td>
#       <td>DPCOAK</td>
#       <td>atp_c + dpcoa_c --&gt; adp_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.03%</td>
#       <td>-0.02538</td>
#       <td>DTMPK</td>
#       <td>atp_c + dtmp_c &lt;=&gt; adp_c + dtdp_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.006514</td>
#       <td>FE2abc</td>
#       <td>atp_c + fe2_e + h2o_c --&gt; adp_c + fe2_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.007574</td>
#       <td>FE3abc</td>
#       <td>atp_c + fe3_e + h2o_c --&gt; adp_c + fe3_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002163</td>
#       <td>FMNAT</td>
#       <td>atp_c + fmn_c + h_c --&gt; fad_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.002379</td>
#       <td>FTHFLi</td>
#       <td>atp_c + for_c + thf_c --&gt; 10fthf_c + adp_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.2359</td>
#       <td>GK1</td>
#       <td>atp_c + gmp_c &lt;=&gt; adp_c + gdp_c</td>
#     </tr>
#     <tr>
#       <td>3.03%</td>
#       <td>-2.228</td>
#       <td>GLNS</td>
#       <td>atp_c + glu__L_c + nh4_c --&gt; adp_c + gln__L_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.29%</td>
#       <td>-0.2144</td>
#       <td>GLU5K</td>
#       <td>atp_c + glu__L_c --&gt; adp_c + glu5p_c</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.2359</td>
#       <td>GMPS</td>
#       <td>atp_c + nh4_c + xmp_c --&gt; amp_c + gmp_c + 2.0 h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>71.30%</td>
#       <td>-52.5</td>
#       <td>Growth</td>
#       <td>0.000215957436615497 10fthf_c + 0.497466186805283 ala__L_c + 0.000215957436615497 amet_c + 0.286450592337987 arg__L_c + 0.233442241629366 asn__L_c + 0.233442241629366 asp__L_c + 52.4155146188655 atp_c + 0.00504062088602539 ca2_c + 0.00504062088602539 cl_c + 0.000557809343006845 coa_c + 9.68418998275772e-05 cobalt2_c + 0.129291683621802 ctp_c + 0.000686609069777522 cu2_c + 0.0886878118620952 cys__L_c + 0.0253396515088839 datp_c + 0.0261637760764165 dctp_c + 0.0261637760764165 dgtp_c + 0.0253396515088839 dttp_c + 0.000215957436615497 fad_c + 0.00650293357342181 fe2_c + 0.00756141553853723 fe3_c + 0.254849143586252 gln__L_c + 0.254849143586252 glu__L_c + 0.593290278265672 gly_c + 0.208303052853126 gtp_c + 47.0666420920129 h2o_c + 0.0917460790586501 his__L_c + 0.281353803150062 ile__L_c + 0.189028609530443 k_c + 0.436302779712182 leu__L_c + 0.332323631867312 lys__L_c + 0.14883244216901 met__L_c + 0.00840103481004232 mg2_c + 0.000215957436615497 mlthf_c + 0.000669177527808559 mn2_c + 9.68418998275772e-05 mql8_c + 0.00177317518584294 nad_c + 0.00043288329222927 nadp_c + 0.179414145715561 phe__L_c + 0.214073861663851 pro__L_c + 0.000215957436615497 pydx5p_c + 0.000215957436615497 ribflv_c + 0.208977072475925 ser__L_c + 0.0042010016145203 so4_c + 0.000215957436615497 thf_c + 0.000215957436615497 thmpp_c + 0.245675310415586 thr__L_c + 0.0550478411189897 trp__L_c + 0.133541106186236 tyr__L_c + 0.0968418998275772 uaagmda_c + 0.139553051327532 utp_c + 0.409798120148372 val__L_c + 0.000330230878412038 zn2_c --&gt; 52.2462049569779 adp_c + 52.2462049569779 h_c + 52.2420039553634 pi_c + 0.749462368022615 ppi_c</td>
#     </tr>
#     <tr>
#       <td>4.85%</td>
#       <td>-3.569</td>
#       <td>HEX1</td>
#       <td>atp_c + glc__D_c --&gt; adp_c + g6p_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0003133</td>
#       <td>METAT</td>
#       <td>atp_c + h2o_c + met__L_c --&gt; amet_c + pi_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0004336</td>
#       <td>NADK</td>
#       <td>atp_c + nad_c --&gt; adp_c + h_c + nadp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.00221</td>
#       <td>NADS1</td>
#       <td>atp_c + dnad_c + nh4_c --&gt; amp_c + h_c + nad_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.71%</td>
#       <td>-0.526</td>
#       <td>NDPK1</td>
#       <td>atp_c + gdp_c &lt;=&gt; adp_c + gtp_c</td>
#     </tr>
#     <tr>
#       <td>0.70%</td>
#       <td>-0.5149</td>
#       <td>NDPK2</td>
#       <td>atp_c + udp_c &lt;=&gt; adp_c + utp_c</td>
#     </tr>
#     <tr>
#       <td>1.45%</td>
#       <td>-1.068</td>
#       <td>NDPK3</td>
#       <td>atp_c + cdp_c &lt;=&gt; adp_c + ctp_c</td>
#     </tr>
#     <tr>
#       <td>0.03%</td>
#       <td>-0.02538</td>
#       <td>NDPK4</td>
#       <td>atp_c + dtdp_c &lt;=&gt; adp_c + dttp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.00221</td>
#       <td>NNATr</td>
#       <td>atp_c + h_c + nicrnt_c &lt;=&gt; dnad_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0005587</td>
#       <td>PANTS</td>
#       <td>ala_B_c + atp_c + pant__R_c --&gt; amp_c + h_c + pnto__R_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.51%</td>
#       <td>-0.3755</td>
#       <td>PFK</td>
#       <td>atp_c + f6p_c --&gt; adp_c + fdp_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002163</td>
#       <td>PMPK</td>
#       <td>4ampm_c + atp_c --&gt; 2mahmp_c + adp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0005587</td>
#       <td>PNTK</td>
#       <td>atp_c + pnto__R_c

# %%
#Testing some cobramod functionalities 
from IPython.display import display
from cobramod import __version__
from cobra import __version__ as cobra_version
print(f'CobraMod version: {__version__}')
print(f'COBRApy version: {cobra_version}')
# Out:
# CobraMod version: 1.1.0
# COBRApy version: 0.24.0

# %%
import escher

# %%
escher.rc['never_ask_before_quit'] = True

# %%
#Lets see which databases are available
from cobramod import available_databases

available databases

# %%
# Out:
# CobraMod supports BioCyc, the Plant Metabolic Network (PMN), Sol Genomics Network (SolCyc), KEGG and BiGG Models repository. BioCyc includes around 18.000 sub-databases and a complete list for BioCyc can be found at 'https://biocyc.org/biocyc-pgdb-list.shtml'. The database-specific identifiers can be found in the URL of the respective data. For instance, for "diphosphate" this is:
#
# BioCyc, sub-database ECOLI -> https://biocyc.org/compound?orgid=ECOLI&id=PPI ->
# PPI
# Plant Metabolic Network, sub-database CORN ->
# https://pmn.plantcyc.org/compound?orgid=CORN&id=PPI -> PPI
#
# Sol Genomics Network, sub-database SolanaCyc ->
# https://solcyc.sgn.cornell.edu/compound?orgid=SOLANACYC&id=PPI
#
# KEGG -> https://www.genome.jp/entry/C00013 -> C00013
#
# BiGG Models Repository,universal model
#  -> http://bigg.ucsd.edu/universal/metabolites/ppi -> ppi
#
# CobraMod uses abbreviations to represent the databases or sub-databases:
#
# Database -> Abbreviation
# BioCyc -> META or identifier of sub-database e.g:
# ECOLI, ARA, GCF_000010885
# Plant Metabolic Network -> pmn:PLANT or identifier
# of sub-database e.g pmn:ARA, pmn:CORN
# KEGG -> KEGG
# BiGG Models Repository ->
# BIGG
