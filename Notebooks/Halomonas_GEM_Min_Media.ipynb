# %%
# %%capture
pip install cobra

# %%
import cobra

# %%
#All these models in this code block are those initially annotated with RAST. but for the sae of the thesis i want to use those from PROKKA, it also gives better info with MEMOTE.

model1path = "/content/drive/MyDrive/Halomonas_Model_devt/HalomonasModelFBC.xml"
model2path = "/content/drive/MyDrive/Halomonas_Model_devt/Halomonas_COBRAModel.xml"
model3path = "/content/drive/MyDrive/Halomonas_Model_devt/Halomonas_annotation_feature_dna_Model.xml"

# %%
#model with annotation from PROKKA
modelpath = "/content/drive/MyDrive/Halomonas_Model_devt/Halomonas_RAST.xml"

# %%
model = cobra.io.read_sbml_model(modelpath)

# %%
model1 = cobra.io.read_sbml_model(model1path)
model2 = cobra.io.read_sbml_model(model2path)
model3 = cobra.io.read_sbml_model(model3path)

# %%
model
# Out:
# <Model Halomonas_RAST at 0x7f3702bf9310>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 53.42102842741748</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4abut_e</td>
#       <td>EX_4abut_e</td>
#       <td>78.94</td>
#       <td>4</td>
#       <td>3.10%</td>
#     </tr>
#     <tr>
#       <td>adn_e</td>
#       <td>EX_adn_e</td>
#       <td>25.12</td>
#       <td>10</td>
#       <td>2.47%</td>
#     </tr>
#     <tr>
#       <td>akg_e</td>
#       <td>EX_akg_e</td>
#       <td>948.3</td>
#       <td>5</td>
#       <td>46.58%</td>
#     </tr>
#     <tr>
#       <td>ala_B_e</td>
#       <td>EX_ala_B_e</td>
#       <td>0.0298</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>15.3</td>
#       <td>6</td>
# ...

# %%
model2.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 66.17995195286184</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3mb[C_e]</td>
#       <td>EX_3mb_e</td>
#       <td>28.87</td>
#       <td>5</td>
#       <td>0.83%</td>
#     </tr>
#     <tr>
#       <td>LalaDgluMdap[C_e]</td>
#       <td>EX_LalaDgluMdap_e</td>
#       <td>6.409</td>
#       <td>15</td>
#       <td>0.55%</td>
#     </tr>
#     <tr>
#       <td>LalaLglu[C_e]</td>
#       <td>EX_LalaLglu_e</td>
#       <td>33.6</td>
#       <td>8</td>
#       <td>1.54%</td>
#     </tr>
#     <tr>
#       <td>acac[C_e]</td>
#       <td>EX_acac_e</td>
#       <td>5.102</td>
#       <td>4</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>acgam[C_e]</td>
#       <td>EX_acgam_e</td>
# ...

# %%
model3.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 66.17995195286184</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3mb_e</td>
#       <td>EX_3mb_e</td>
#       <td>28.87</td>
#       <td>5</td>
#       <td>0.83%</td>
#     </tr>
#     <tr>
#       <td>LalaDgluMdap_e</td>
#       <td>EX_LalaDgluMdap_e</td>
#       <td>6.409</td>
#       <td>15</td>
#       <td>0.55%</td>
#     </tr>
#     <tr>
#       <td>LalaLglu_e</td>
#       <td>EX_LalaLglu_e</td>
#       <td>33.6</td>
#       <td>8</td>
#       <td>1.54%</td>
#     </tr>
#     <tr>
#       <td>acac_e</td>
#       <td>EX_acac_e</td>
#       <td>5.102</td>
#       <td>4</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>acgam_e</td>
#       <td>EX_acgam_e</td>
#       <td>12.82</td>
# ...

# %%
##Here i obtained a sample medium of Chromohalobacter to start minimal media simulations with Halomonas
test = cobra.io.read_sbml_model('/content/drive/MyDrive/Model_devt_Ch/(Ect+PHB)ModelCanadensis.xml')
Sample_medium = test.medium
Sample_medium

# %%
model1.medium = Sample_medium
moodel1.optimize()# didnt produce any growth. So does not want the medium of Chromohalobacter

# %%
#lets find its own medium
medium = model.medium
medium
# Out:
# {'EX_14glucan_e': 1000.0,
#  'EX_15dap_e': 1000.0,
#  'EX_2ddglcn_e': 1000.0,
#  'EX_2hxmp_e': 1000.0,
#  'EX_2pglyc_e': 1000.0,
#  'EX_34dhbz_e': 1000.0,
#  'EX_34dhcinm_e': 1000.0,
#  'EX_34dhpac_e': 1000.0,
#  'EX_3hoxpac_e': 1000.0,
#  'EX_3mb_e': 1000.0,
#  'EX_4abut_e': 1000.0,
#  'EX_4hbz_e': 1000.0,
#  'EX_4hphac_e': 1000.0,
#  'EX_4hthr_e': 1000.0,
#  'EX_5mtr_e': 1000.0,
#  'EX_LalaDgluMdapDala_e': 1000.0,
#  'EX_LalaDgluMdap_e': 1000.0,
#  'EX_LalaDglu_e': 1000.0,
#  'EX_LalaLglu_e': 1000.0,
#  'EX_Larab_e': 1000.0,
#  'EX_T4hcinnm_e': 1000.0,
#  'EX_ac_e': 1000.0,
#  'EX_acac_e': 1000.0,
#  'EX_acald_e': 1000.0,
#  'EX_acgam_e': 1000.0,
#  'EX_acmana_e': 1000.0,
#  'EX_acmum_e': 1000.0,
#  'EX_acser_e': 1000.0,
#  'EX_actn__R_e': 1000.0,
#  'EX_ade_e': 1000.0,
#  'EX_adn_e': 1000.0,
#  'EX_agm_e': 1000.0,
#  'EX_ala__D_e': 1000.0,
#  'EX_ala__L_e': 1000.0,
#  'EX_alaala_e': 1000.0,
#  'EX_alltn_e': 1000.0,
#  'EX_anhgm_e': 1000.0,
#  'EX_arab__D_e': 1000.0,
# ...

# %%
#This is the minimal medium requied for the Halomonas to grow
min_medium = {'EX_ca2_e': 1000.0,
 'EX_cl_e': 1000.0,
 #'EX_co2_e': 1000.0,
 'EX_cobalt2_e': 1000.0,
 'EX_cu2_e': 1000.0,
 #'EX_fe2_e': 1000.0,
 'EX_fe3_e': 1000.0,
 'EX_glc__D_e': 1000.0,
 'EX_asn__L_e': 1000.0,
 #'EX_h2_e': 1000.0,
 #'EX_h2o2_e': 1000.0,
 'EX_h2o_e': 1000.0,
 'EX_k_e': 1000.0,
 'EX_mg2_e': 1000.0,
 'EX_mn2_e': 1000.0,
 #'EX_mobd_e': 1000.0,
 #'EX_nh4_e': 1000.0,
 #'EX_no2_e': 1000.0,
 #'EX_no3_e': 1000.0,
 #'EX_no_e': 1000.0,
 'EX_o2_e': 1000.0,
 'EX_pi_e': 1000.0,
 #'EX_s_e': 1000.0,
 #'EX_so3_e': 1000.0,
 'EX_bz_e' : 0.000097,
 'EX_so4_e': 1000.0,
 'EX_zn2_e': 1000.0}

model.medium = min_medium

model.optimize()
# Out:
# <Solution 1.002 at 0x7f36faa785d0>

# %%
model.medium
# Out:
# {'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_glc__D_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
from cobra.medium import minimal_medium
minimal_medium(model, 1.0, minimize_components=True)
# Out:
# EX_cl_e            0.005041
# EX_asn__L_e     1000.000000
# EX_fe3_e           0.014064
# EX_k_e             0.189029
# EX_bz_e            0.000097
# EX_ca2_e           0.005041
# EX_mg2_e           0.008401
# EX_mn2_e           0.000669
# EX_cobalt2_e       0.000097
# EX_zn2_e           0.000330
# EX_cu2_e           0.000687
# EX_o2_e          535.556454
# EX_malthp_e       85.618781
# EX_udcpdp_e        0.954951
# EX_so4_e           0.242711
# dtype: float64

# %%
min_medium2 = {
'EX_cl_e' :    0.005041,
'EX_asn__L_e':1000.00000,
'EX_fe3_e':  0.014064,
'EX_k_e' : 0.189029,
'EX_bz_e' :0.000097,
'EX_ca2_e' :0.005041,
'EX_mg2_e':0.008401,
'EX_mn2_e':0.000669,
'EX_cobalt2_e' :0.000097,
'EX_zn2_e' :0.000330,
'EX_cu2_e' :0.000687,
'EX_o2_e' :535.556454,
#'EX_malthp_e':85.618781,
#'EX_udcpdp_e' :0.954951,
'EX_so4_e':0.242711, ####
'EX_pi_e': 1000.0,
'EX_glc__D_e': 1000.0,
'EX_nh4_e': 1000.0,
}

# %%
model.medium = min_medium2
model.optimize()
# Out:
# <Solution 0.999 at 0x7f36fa2dd550>

# %%
#lets get glucose conc sorted out
min_medium['EX_glc__D_e'] = 10.0
model.reactions.EX_glc__D_e = -10.0
model.medium = min_medium
model.medium
# Out:
# {'EX_asn__L_e': 1000.0,
#  'EX_bz_e': 9.7e-05,
#  'EX_ca2_e': 1000.0,
#  'EX_cl_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_glc__D_e': 10.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
#predictions with model from PROKKA seem to give a need for more curation, a lot of carbon is secreted out as lactate,I havent got any explanation for it at this point
#growth is low and plenty carbon is sent out as lactate

model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 1.001632559591502</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>5.431</td>
#       <td>4</td>
#       <td>31.36%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>9.7E-05</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.005049</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>9.7E-05</td>
#       <td>0</td>
# ...

# %%
Path2SaveModel  = "/content/drive/MyDrive/Halomonas_Model_devt"
cobra.io.write_sbml_model(model, "/content/drive/MyDrive/Halomonas_Model_devt/Halomonas_RASTV1.xml" )

# %%
from cobra import Model, Reaction, Metabolite
#model = Model('example_model')

reaction = Reaction('DM_PHB_c')
reaction.name = 'PHB Demand reaction'
reaction.subsystem = 'Butanoate metabolism'
reaction.lower_bound = 0.  # This is the default
reaction.upper_bound = 1000.  # This is the default
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6397c67d5bbb> in <module>()
# ----> 1 from cobra import Model, Reaction, Metabolite
#       2 #model = Model('example_model')
#       3
#       4 reaction = Reaction('DM_PHB_c')
#       5 reaction.name = 'PHB Demand reaction'
#
# ModuleNotFoundError: No module named 'cobra'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
